# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"C:\Users\win 11\Downloads\archive (1).zip")

# %%
df
# Out:
#     body_weight  brain_weight max_life_span gestation_time  predation_index  \
# 0      6654.000        5712.0          38.6            645                3
# 1         1.000           6.6           4.5             42                3
# 2         3.385          44.5            14             60                1
# 3         0.920           5.7             ?             25                5
# 4      2547.000        4603.0            69            624                3
# ..          ...           ...           ...            ...              ...
# 57        2.000          12.3           7.5            200                3
# 58        0.104           2.5           2.3             46                3
# 59        4.190          58.0            24            210                4
# 60        3.500           3.9             3             14                2
# 61        4.050          17.0            13             38                3
#
#     sleep_exposure_index  danger_index total_sleep
# ...

# %%
df.columns
# Out:
# Index(['body_weight', 'brain_weight', 'max_life_span', 'gestation_time',
#        'predation_index', 'sleep_exposure_index', 'danger_index',
#        'total_sleep'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   body_weight           62 non-null     float64
#  1   brain_weight          62 non-null     float64
#  2   max_life_span         62 non-null     object
#  3   gestation_time        62 non-null     object
#  4   predation_index       62 non-null     int64
#  5   sleep_exposure_index  62 non-null     int64
#  6   danger_index          62 non-null     int64
#  7   total_sleep           62 non-null     object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 4.0+ KB

# %%
df.describe()
# Out:
#        body_weight  brain_weight  predation_index  sleep_exposure_index  \
# count    62.000000     62.000000        62.000000             62.000000
# mean    198.789984    283.134194         2.870968              2.419355
# std     899.158011    930.278942         1.476414              1.604792
# min       0.005000      0.140000         1.000000              1.000000
# 25%       0.600000      4.250000         2.000000              1.000000
# 50%       3.342500     17.250000         3.000000              2.000000
# 75%      48.202500    166.000000         4.000000              4.000000
# max    6654.000000   5712.000000         5.000000              5.000000
#
#        danger_index
# count     62.000000
# mean       2.612903
# std        1.441252
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        4.000000
# max        5.000000

# %%
df.head()
# Out:
#    body_weight  brain_weight max_life_span gestation_time  predation_index  \
# 0     6654.000        5712.0          38.6            645                3
# 1        1.000           6.6           4.5             42                3
# 2        3.385          44.5            14             60                1
# 3        0.920           5.7             ?             25                5
# 4     2547.000        4603.0            69            624                3
#
#    sleep_exposure_index  danger_index total_sleep
# 0                     5             3         3.3
# 1                     1             3         8.3
# 2                     1             1        12.5
# 3                     2             3        16.5
# 4                     5             4         3.9

# %%
df.tail()
# Out:
#     body_weight  brain_weight max_life_span gestation_time  predation_index  \
# 57        2.000          12.3           7.5            200                3
# 58        0.104           2.5           2.3             46                3
# 59        4.190          58.0            24            210                4
# 60        3.500           3.9             3             14                2
# 61        4.050          17.0            13             38                3
#
#     sleep_exposure_index  danger_index total_sleep
# 57                     1             3         5.4
# 58                     2             2        15.8
# 59                     3             4        10.3
# 60                     1             1        19.4
# 61                     1             1           ?

# %%
df.columns
# Out:
# Index(['body_weight', 'brain_weight', 'max_life_span', 'gestation_time',
#        'predation_index', 'sleep_exposure_index', 'danger_index',
#        'total_sleep'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['body_weight'],df['danger_index'])
plt.xlabel("body_weight")
plt.ylabel("danger_index")
plt.show()

# %%
def bar_plot(variable):
    var=df[variable]
    varValue=var.value_counts()
    plt.figure(figsize=(9,3))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}:\n {}".format(variable,varValue))

# %%
df.columns
# Out:
# Index(['body_weight', 'brain_weight', 'max_life_span', 'gestation_time',
#        'predation_index', 'sleep_exposure_index', 'danger_index',
#        'total_sleep'],
#       dtype='object')

# %%
columns_plot=['body_weight','max_life_span','danger_index','gestation_time','total_sleep']
for i in columns_plot:
    bar_plot(i)
# Out:
# body_weight:
#  body_weight
# 0.023       2
# 3.500       2
# 6654.000    1
# 4.288       1
# 62.000      1
# 0.122       1
# 1.350       1
# 0.048       1
# 1.700       1
# 250.000     1
# 0.480       1
# 10.000      1
# 1.620       1
# 192.000     1
# 2.500       1
# 0.280       1
# 0.005       1
# 4.235       1
# 6.800       1
# 0.750       1
# 3.600       1
# 14.830      1
# 55.500      1
# 1.400       1
# 0.060       1
# 0.900       1
# 2.000       1
# 0.104       1
# 4.190       1
# 0.010       1
# 35.000      1
# 1.000       1
# 3.000       1
# 3.385       1
# 0.920       1
# 2547.000    1
# 10.550      1
# 160.000     1
# 3.300       1
# 52.160      1
# 0.425       1
# 465.000     1
# 0.550       1
# 187.100     1
# 0.075       1
# 0.785       1
# 100.000     1
# 0.200       1
# 1.410       1
# 60.000      1
# 529.000     1
# 27.660      1
# 0.120       1
# 207.000     1
# 85.000      1
# 36.330      1
# 0.101       1
# 1.040       1
# 521.000     1
# 4.050       1
# ...

# %%
df.columns
# Out:
# Index(['body_weight', 'brain_weight', 'max_life_span', 'gestation_time',
#        'predation_index', 'sleep_exposure_index', 'danger_index',
#        'total_sleep'],
#       dtype='object')

# %%
def hist_plot(variable):
    var=df[variable]
    varValue=var.value_counts()
    plt.figure(figsize=(9,3))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}:\n {}".format(variable,varValue))

# %%
cc=['body_weight', 'danger_index','total_sleep']
for i in cc :
    hist_plot(i)
# Out:
# body_weight:
#  body_weight
# 0.023       2
# 3.500       2
# 6654.000    1
# 4.288       1
# 62.000      1
# 0.122       1
# 1.350       1
# 0.048       1
# 1.700       1
# 250.000     1
# 0.480       1
# 10.000      1
# 1.620       1
# 192.000     1
# 2.500       1
# 0.280       1
# 0.005       1
# 4.235       1
# 6.800       1
# 0.750       1
# 3.600       1
# 14.830      1
# 55.500      1
# 1.400       1
# 0.060       1
# 0.900       1
# 2.000       1
# 0.104       1
# 4.190       1
# 0.010       1
# 35.000      1
# 1.000       1
# 3.000       1
# 3.385       1
# 0.920       1
# 2547.000    1
# 10.550      1
# 160.000     1
# 3.300       1
# 52.160      1
# 0.425       1
# 465.000     1
# 0.550       1
# 187.100     1
# 0.075       1
# 0.785       1
# 100.000     1
# 0.200       1
# 1.410       1
# 60.000      1
# 529.000     1
# 27.660      1
# 0.120       1
# 207.000     1
# 85.000      1
# 36.330      1
# 0.101       1
# 1.040       1
# 521.000     1
# 4.050       1
# ...

# %%
df.columns
# Out:
# Index(['body_weight', 'brain_weight', 'max_life_span', 'gestation_time',
#        'predation_index', 'sleep_exposure_index', 'danger_index',
#        'total_sleep'],
#       dtype='object')

# %%
df[['max_life_span','body_weight']].groupby(['max_life_span'],as_index =False).mean().sort_values(by='body_weight',ascending=False)
# Out:
#    max_life_span  body_weight
# 30          38.6  6654.000000
# 41            69  2547.000000
# 36            46   521.000000
# 27            30   465.000000
# 21            28   266.150000
# 18          23.6   250.000000
# 31          39.3   207.000000
# 34            40   187.100000
# 28          30.4   160.000000
# 20            27   101.275000
# 17          22.4   100.000000
# 35            41    85.000000
# 1            100    62.000000
# 15            20    41.580000
# 7           16.2    36.330000
# 8           16.3    35.000000
# 38            50    27.580000
# 42             7    20.391667
# 9             17    14.830000
# 16          20.2    10.000000
# 22            29     6.800000
# 5           13.7     4.288000
# 46           9.8     4.235000
# 23             3     3.500000
# 40           6.5     3.500000
# 6             14     3.385000
# 4             13     2.835000
# 10            18     2.500000
# 39             6     2.192500
# 19            24     2.100000
# ...

# %%
sns.boxplot(df['danger_index'])
# Out:
# <Axes: ylabel='danger_index'>

# %%
df['danger_index']=df['danger_index'].fillna(df['danger_index'].median())

# %%
df['body_weight']=df['body_weight'].fillna(df['body_weight']).median()

# %%
df.isnull().sum()
# Out:
# body_weight             0
# brain_weight            0
# max_life_span           0
# gestation_time          0
# predation_index         0
# sleep_exposure_index    0
# danger_index            0
# total_sleep             0
# dtype: int64

# %%
df['brain_weight'].mode()
# Out:
# 0      1.0
# 1     12.3
# 2    115.0
# Name: brain_weight, dtype: float64

# %%
 df.drop(labels=[])
# Out:
#     body_weight  brain_weight max_life_span gestation_time  predation_index  \
# 0        3.3425        5712.0          38.6            645                3
# 1        3.3425           6.6           4.5             42                3
# 2        3.3425          44.5            14             60                1
# 3        3.3425           5.7             ?             25                5
# 4        3.3425        4603.0            69            624                3
# ..          ...           ...           ...            ...              ...
# 57       3.3425          12.3           7.5            200                3
# 58       3.3425           2.5           2.3             46                3
# 59       3.3425          58.0            24            210                4
# 60       3.3425           3.9             3             14                2
# 61       3.3425          17.0            13             38                3
#
#     sleep_exposure_index  danger_index total_sleep
# ...

# %%
pd.get_dummies(df)
df.head()
# Out:
#    body_weight  brain_weight max_life_span gestation_time  predation_index  \
# 0       3.3425        5712.0          38.6            645                3
# 1       3.3425           6.6           4.5             42                3
# 2       3.3425          44.5            14             60                1
# 3       3.3425           5.7             ?             25                5
# 4       3.3425        4603.0            69            624                3
#
#    sleep_exposure_index  danger_index total_sleep
# 0                     5             3         3.3
# 1                     1             3         8.3
# 2                     1             1        12.5
# 3                     2             3        16.5
# 4                     5             4         3.9

# %%
df = df.drop_duplicates()
df = df.dropna()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["brain_weight"], bins=30, kde=True)
plt.title("Distribution of brain_weight")
plt.xlabel("brain_weight (kg)")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x=df["brain_weight"])
plt.title("brain_weight Outliers")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["body_weight"], y=df["brain_weight"])
plt.title("brain_weight vs body_weight")
plt.show()

# %%
import numpy as np

# %%
rs=np.random.RandomState(10)
d=rs.normal(size=100)
sns.histplot(d,kde=True,color='r')
# Out:
# <Axes: ylabel='Count'>

# %%
df.columns
# Out:
# Index(['body_weight', 'brain_weight', 'max_life_span', 'gestation_time',
#        'predation_index', 'sleep_exposure_index', 'danger_index',
#        'total_sleep'],
#       dtype='object')

# %%
fmri=sns.load_dataset('fmri')
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
df=sns.load_dataset('anscombe')
df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
sns.lmplot(x='x',y='y',data=df)

# %%
sns.pairplot(df)
